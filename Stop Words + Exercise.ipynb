# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp("We just opened our wings, the flying part is coming soon")
for token in doc:
    if token.is_stop:
        print(token)
# Out:
# We
# just
# our
# the
# part
# is

# %%
def preprocess(text):
    doc = nlp(text)
    no_stop_words = [token.text for token in doc if not token.is_stop and not token.is_punct]
    #return no_stop_words #returns list
    return " ".join(no_stop_words) # returns string

# %%
preprocess("We just opened our wings, the flying part is coming soon")
# Out:
# 'opened wings flying coming soon'

# %%
import pandas as pd
df = pd.read_json("/Users/admin/Documents/nlp-tutorials/combined.json",lines = True)
df.shape
# Out:
# (13087, 6)

# %%
df.head(5)
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
# 2  11-1002  $1 Million Settlement Reached for Natural Reso...
# 3   10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4   18-898  $100 Million Settlement Will Speed Cleanup Wor...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
# 2        BOSTON– A $1-million settlement has been...
# 3    WASHINGTON—A federal grand jury in Las Vegas...
# 4  The U.S. Department of Justice, the U.S. Envir...
#
#                         date         topics  \
# 0  2014-10-01T00:00:00-04:00             []
# 1  2012-07-25T00:00:00-04:00             []
# 2  2011-08-03T00:00:00-04:00             []
# 3  2010-01-08T00:00:00-05:00             []
# ...

# %%
df = df.head(100)
df.shape
# Out:
# (100, 6)

# %%
len(df["contents"].iloc[4])
# Out:
# 6286

# %%
#new column
df["contents_new"] = df["contents"].apply(preprocess)
df.head(5)
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
# 2  11-1002  $1 Million Settlement Reached for Natural Reso...
# 3   10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4   18-898  $100 Million Settlement Will Speed Cleanup Wor...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
# 2        BOSTON– A $1-million settlement has been...
# 3    WASHINGTON—A federal grand jury in Las Vegas...
# 4  The U.S. Department of Justice, the U.S. Envir...
#
#                         date         topics  \
# 0  2014-10-01T00:00:00-04:00             []
# 1  2012-07-25T00:00:00-04:00             []
# 2  2011-08-03T00:00:00-04:00             []
# 3  2010-01-08T00:00:00-05:00             []
# ...

# %%
len(df["contents_new"].iloc[4])
# Out:
# 4574

# %%
#Stop Words Exercise
text = '''
Thor: Love and Thunder is a 2022 American superhero film based on Marvel Comics featuring the character Thor, produced by Marvel Studios and 
distributed by Walt Disney Studios Motion Pictures. It is the sequel to Thor: Ragnarok (2017) and the 29th film in the Marvel Cinematic Universe (MCU).
The film is directed by Taika Waititi, who co-wrote the script with Jennifer Kaytin Robinson, and stars Chris Hemsworth as Thor alongside Christian Bale, Tessa Thompson,
Jaimie Alexander, Waititi, Russell Crowe, and Natalie Portman. In the film, Thor attempts to find inner peace, but must return to action and recruit Valkyrie (Thompson),
Korg (Waititi), and Jane Foster (Portman)—who is now the Mighty Thor—to stop Gorr the God Butcher (Bale) from eliminating all gods.
'''
doc = nlp(text)

# %%
total_stop_words = 0
total_words = 0
for token in doc:
    if token.is_stop:
        total_stop_words+=1
    total_words+=1
        
print("Total words = ",total_words)
print("Total Stop words = ",total_stop_words)
# Out:
# Total words =  160
# Total Stop words =  40

# %%
percentage_stop_words = (total_stop_words / total_words)*100
print("Percentage of stop words: ",percentage_stop_words)
# Out:
# Percentage of stop words:  25.0

# %%
positive_text = "this is a good movie"
negative_text = "this is not a good movie"
nlp.vocab["not"].is_stop = False

positive_text = preprocess(positive_text)
negative_text = preprocess(negative_text)
print(positive_text)
print(negative_text)
# Out:
# good movie
# not good movie

# %%
text = text = ''' The India men's national cricket team, also known as Team India or the Men in Blue, represents India in men's international cricket.
It is governed by the Board of Control for Cricket in India (BCCI), and is a Full Member of the International Cricket Council (ICC) with Test,
One Day International (ODI) and Twenty20 International (T20I) status. Cricket was introduced to India by British sailors in the 18th century, and the 
first cricket club was established in 1792. India's national cricket team played its first Test match on 25 June 1932 at Lord's, becoming the sixth team to be
granted test cricket status.
'''
doc = nlp(text)

# %%
token_counts = {}
remaining_tokens = []

for token in doc:
    if token.is_stop and not token.is_punct:
        remaining_tokens.append(token.text)

for token in remaining_tokens:
    if token !="\n" and token != ' ':
        if token not in token_counts:
            token_counts[token] = 1
        else:
            token_counts[token] += 1

for token,count in token_counts.items():
    print(token, " : ", count)
# Out:
# The  :  1
# 's  :  4
# also  :  1
# as  :  1
# or  :  1
# the  :  6
# in  :  5
# It  :  1
# is  :  2
# by  :  2
# of  :  2
# for  :  1
# and  :  3
# a  :  1
# Full  :  1
# with  :  1
# One  :  1
# was  :  2
# to  :  2
# first  :  2
# its  :  1
# on  :  1
# at  :  1
# becoming  :  1
# be  :  1
